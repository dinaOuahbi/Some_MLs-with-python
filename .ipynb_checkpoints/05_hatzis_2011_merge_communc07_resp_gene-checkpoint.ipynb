# %%
import pandas as pd
import os
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !ls
# Out:
#  03_Lisowska_2014_merg.csv
#  04_iwamoto_2011.ipynb
#  04_iwamoto_2011_merge.csv
# '05_hatzis_2011_mccf1 scores all original features_bf.png'
# '05_hatzis_2011_mccf1 scores all original features_cv.png'
# '05_hatzis_2011_mccf1 scores all original features.png'
# '05_hatzis_2011_mccf1 scores all original features_rb_cv.png'
# '05_hatzis_2011_mccf1 scores all original features_rb.png'
#  05_hatzis_2011_merge_communc07_resp_gene.csv
#  05_hatzis_2011_merge_communc07_resp_gene.ipynb
# '07_Magbanua MJ_2015_merge_resp_gene.csv'
# 'mccf1 scores all original features.png'
#  TTS_RECIST_GEX_MLclassification.ipynb

# %%
# !pwd
# Out:
# /home/ouahbi/environment/dina datasets/Chemoterapy_cohorts/commun_data/c5-c7

# %%
c5 = pd.read_csv('05_hatzis_2011_merge_communc07_resp_gene.csv', sep='\t')
c5.head()
# Out:
#      Patient      response      RFC2       PAX8    GUCA1A      THRA    PTPN21  \
# 0  GSM615096  NonResponder  8.021741  10.840949  7.874062  8.256335  6.485966
# 1  GSM615097  NonResponder  7.842947  11.715159  7.347955  7.983681  7.330512
# 2  GSM615098  NonResponder  8.776267  10.715077  6.523880  7.820261  6.423794
# 3  GSM615099     Responder  9.523877  10.750475  6.478643  7.526617  7.276040
# 4  GSM615100  NonResponder  6.836237  10.827725  7.336754  8.312127  6.832232
#
#         CCL5    CYP2E1      EPHB3  ...      TRDN   OR7E47P     SCAF4  \
# 0   6.495728  7.063123   8.539362  ...  5.258077  6.224040  7.278666
# 1   7.332244  7.033859   9.188714  ...  2.585735  5.834062  6.669256
# 2  10.066291  6.661108  10.387343  ...  6.183848  7.720553  6.950571
# 3  10.399704  6.642930   9.836355  ...  3.395661  5.730234  7.118569
# 4   7.090151  7.081613   8.918156  ...  2.324113  5.336347  7.290629
#
#      ALS2CL     LAMA1    FBXO31   SLC44A1    NUS1P3    RBM12B    NPEPL1
# ...

# %%
print(c5.shape)
print(c5.dtypes.unique().tolist())
c5.dtypes.value_counts(normalize=True)
# Out:
# (306, 8995)
# [dtype('O'), dtype('float64')]
# float64    0.999778
# object     0.000222
# dtype: float64

# %%
c5.set_index('Patient', inplace=True)

# %%
c5['response']=c5['response'].map({'NonResponder':0, 'Responder':1})

# %%
c5.isna().sum(axis=0).sort_values(ascending=False).head(5)
# Out:
# NPEPL1     0
# ITGBL1     0
# BMP5       0
# MPP6       0
# ZNF354A    0
# dtype: int64

# %%
c5.iloc[:,0].value_counts(normalize=True).round(2).plot.bar()

# %%
#split
X = c5.drop('response', axis=1)
y = c5['response']

print(X.shape, y.shape)
# Out:
# (306, 8993) (306,)

# %%
# dist of some genes expression 
plt.figure(figsize=(10,5))
for col in X.columns[:100]:
    sns.distplot(X[col], hist=False)
    plt.grid(True)

# %%
#untill 100
c5.columns.get_loc('YWHAZ')
# Out:
# 100

# %%
X.std(axis=0).sort_values(ascending=False).head()
# Out:
# AGR2       3.761116
# SCGB2A2    3.600154
# S100A7     3.403502
# LTF        3.334582
# GABRP      3.217137
# dtype: float64

# %%
#let's see if best two features can separate our patient
plt.scatter(x = 'AGR2', y = 'SCGB2A2', data=X, c=y, cmap='plasma')
plt.xlabel('AGR2')
plt.ylabel('scgb2a2')
plt.grid(True)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X['AGR2'], X['SCGB2A2'],X['S100A7'], c=y, cmap='plasma')
ax.set_xlabel('AG')
ax.set_ylabel('SC')
ax.set_zlabel('S1')
plt.show()

# %% [markdown]
# ===> small ccl :
# - shape of data : (306, 8995)
# - types of data : one object and 8993 floats
# - unbalance data
#     - mcc / score f1
# - no scall data
#     - robustscaller / minmax

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

print('train shape ===> ',X_train.shape)
print('test shape ===> ',X_test.shape)
# Out:
# train shape ===>  (229, 8993)
# test shape ===>  (77, 8993)

# %%
#pca-dt / dt/ stack / knn

# %% [markdown]
# # tts-all feature

# %%
# IMPORT CLF

from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, matthews_corrcoef
from sklearn.ensemble import BaggingClassifier

# %%
#models initialisation 
knn = KNeighborsClassifier(n_neighbors=5, p=2)
lr = LogisticRegression(penalty='l2',
                        random_state=0)
rf =RandomForestClassifier(n_estimators = 20, 
                                criterion = 'entropy', 
                                random_state = 51)
svc_lm = SVC(random_state=0, kernel='linear', probability=True)
svc_rbf = SVC(random_state=0, kernel='rbf', probability=True)
dt =  DecisionTreeClassifier(criterion = 'entropy',random_state = 0, max_depth=None)

# make dictionnary
pred_list = {}
mcc_score = {}
score_f1 = {}

#put models inside list 6
models = [knn,lr,rf,svc_lm,svc_rbf,dt]

#fit, predict and evaluate inside for loop
for clf in models:
    clf.fit(X_train, y_train)
    pred_list[clf] = clf.predict(X_test)
    mcc_score[clf] = matthews_corrcoef(y_test, pred_list[clf])
    score_f1[clf] = f1_score(y_test, pred_list[clf])
# Out:
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:873: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)

# %%
list_models = ['knn','lr','rf','svc_lm','svc_rbf','dt']
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.bar(list_models, mcc_score.values(), alpha=0.5, color='red')
plt.grid(True)
plt.title('mcc_TSS')
plt.subplot(122)
plt.bar(list_models, score_f1.values(), alpha=0.5)
plt.grid(True)
plt.title('f1_TSS')
plt.savefig("05_hatzis_2011_TSS.png")

# %%
# chaque model est faible ===> maybe together is more better 
from sklearn.ensemble import AdaBoostClassifier

ab = AdaBoostClassifier(n_estimators=100, random_state=0)
ab.fit(X_train, y_train)
print(matthews_corrcoef(y_test, ab.predict(X_test)))
print(f1_score(y_test, ab.predict(X_test)))
# Out:
# 0.11322770341445958
# 0.24999999999999994

# %% [markdown]
# # cv-all feature

# %%
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(10, shuffle=True)

# make dictionnary
pred_cv = {}
mcc_cv = {}
f1_cv = {}

#model in for loop 
for clf in models:
    np.average(cross_val_score(clf, X, y, cv=cv))
    pred_cv[clf] = cross_val_predict(clf, X, y, cv=cv)
    mcc_cv[clf] = matthews_corrcoef(y, pred_cv[clf])
    f1_cv[clf] = f1_score(y, pred_cv[clf])
# Out:
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
list_models = ['knn','lr','rf','svc_lm','svc_rbf','dt']
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.bar(list_models, mcc_cv.values(), alpha=0.5, color='red')
plt.grid(True)
plt.title('mcc_cv')
plt.subplot(122)
plt.bar(list_models, f1_cv.values(), alpha=0.5)
plt.grid(True)
plt.title('f1_cv')
plt.savefig("05_hatzis_2011_cv.png")

# %% [markdown]
# # tss_sc_all-feature

# %%
#transform data into normal distribution
from sklearn.preprocessing import RobustScaler

X_train_rb = RobustScaler().fit_transform(X_train)
X_test_rb = RobustScaler().fit_transform(X_test)

#check if it's normal
plt.figure(figsize=(15,5))
for row in X_train_rb[1:100]:
    sns.distplot(row, hist=False)
    plt.grid(True)
    plt.title('dist of some genes expression (first 100 genes)')

# %%
# make dictionnary
pred_rb = {}
mcc_rb = {}
f1_rb = {}

#fit, predict and evaluate inside for loop
for clf in models:
    clf.fit(X_train_rb, y_train)
    pred_rb[clf] = clf.predict(X_test_rb)
    mcc_rb[clf] = matthews_corrcoef(y_test, pred_rb[clf])
    f1_rb[clf] = f1_score(y_test, pred_rb[clf])
# Out:
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:873: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.bar(list_models, mcc_rb.values(), alpha=0.5, color='red')
plt.grid(True)
plt.title('mcc_rb')
plt.subplot(122)
plt.bar(list_models, f1_rb.values(), alpha=0.5)
plt.grid(True)
plt.title('f1_rb')
plt.savefig("05_hatzis_2011_rb.png")

# %% [markdown]
# # # cv_sc_all-feature

# %%
#cv
# make dictionnary
pred_rb_cv = {}
mcc_rb_cv = {}
f1_rb_cv = {}

#model in for loop 
for clf in models:
    np.average(cross_val_score(clf, X_train_rb, y_train, cv=cv))
    pred_rb_cv[clf] = cross_val_predict(clf, X_test_rb, y_test, cv=cv)
    mcc_rb_cv[clf] = matthews_corrcoef(y_test, pred_rb_cv[clf])
    f1_rb_cv[clf] = f1_score(y_test, pred_rb_cv[clf])
# Out:
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:873: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:873: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:873: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.bar(list_models, mcc_rb_cv.values(), alpha=0.5, color='red')
plt.grid(True)
plt.title('mcc_rb_cv')
plt.subplot(122)
plt.bar(list_models, f1_rb_cv.values(), alpha=0.5)
plt.grid(True)
plt.title('f1_rb_cv')
plt.savefig("05_hatzis_2011_rb_cv.png")

# %% [markdown]
# # tss_features selection(chie2/k=4000)

# %%
#minmax
#no outlier (see distribution)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_sc = scaler.fit_transform(X)

# %%
X_sc.min()
# Out:
# 0.0

# %%
#freature selection ANOVA
# Feature Selection with Univariate Statistical Tests
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif, chi2

kb = SelectKBest(chi2, k=4000)
best_f = kb.fit_transform(X_sc,y)

# %%
#get the index of best features with get_support function ==> boolean mask
best_f_name = np.array(pd.DataFrame(X).columns)[kb.get_support()]
best_f_name
# Out:
# array(['RFC2', 'PAX8', 'GUCA1A', ..., 'SMEK2', 'OR7E47P', 'NUS1P3'],
#       dtype=object)

# %%
X_train_bf, X_test_bf, y_train_bf, y_test_bf = train_test_split(best_f, y, random_state=0)

print(X_train_bf.shape, X_test_bf.shape)
# Out:
# (229, 4000) (77, 4000)

# %%
# make dictionnary
pred_bf = {}
mcc_bf = {}
f1_bf = {}

#fit, predict and evaluate inside for loop
for clf in models:
    clf.fit(X_train_bf, y_train_bf)
    pred_bf[clf] = clf.predict(X_test_bf)
    mcc_bf[clf] = matthews_corrcoef(y_test_bf, pred_bf[clf])
    f1_bf[clf] = f1_score(y_test_bf, pred_bf[clf])
# Out:
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:873: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)

# %%
f1_bf.values()
# Out:
# dict_values([0.5217391304347826, 0.608695652173913, 0.25, 0.6666666666666666, 0.0, 0.3076923076923077])

# %%
f1_bf.values()
# Out:
# dict_values([0.5217391304347826, 0.608695652173913, 0.25, 0.6666666666666666, 0.0, 0.3076923076923077])

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.bar(list_models, mcc_bf.values(), alpha=0.5, color='red')
plt.grid(True)
plt.title('mcc_bf')
plt.subplot(122)
plt.bar(list_models, f1_bf.values(), alpha=0.5)
plt.grid(True)
plt.title('f1_bf')
plt.savefig("05_hatzis_2011_bf.png")

# %%
mcc_bf.values()
# Out:
# dict_values([0.44467121718097274, 0.5478027946596923, 0.2675837217835722, 0.5965199110453098, 0.0, 0.16706730769230768])

# %% [markdown]
# # cv_feature-selection(chi2/k=4000)

# %%
#cv
# make dictionnary
pred_bf_cv = {}
mcc_bf_cv = {}
f1_bf_cv = {}

#model in for loop 
for clf in models:
    np.average(cross_val_score(clf, X_train_bf, y_train_bf, cv=cv))
    pred_bf_cv[clf] = cross_val_predict(clf, X_test_bf, y_test_bf, cv=cv)
    mcc_bf_cv[clf] = matthews_corrcoef(y_test_bf, pred_bf_cv[clf])
    f1_bf_cv[clf] = f1_score(y_test_bf, pred_bf_cv[clf])
# Out:
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
mcc_bf_cv.values()
# Out:
# dict_values([0.14436532185343598, 0.2569951740823651, 0.20694125707013106, 0.4146437445831808, 0.0, 0.21230194390211168])

# %%
f1_bf_cv.values()
# Out:
# dict_values([0.13333333333333336, 0.3157894736842105, 0.23529411764705882, 0.4761904761904762, 0.0, 0.33333333333333337])

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.bar(list_models, mcc_bf_cv.values(), alpha=0.5, color='red')
plt.grid(True)
plt.title('mcc_bf_cv')
plt.subplot(122)
plt.bar(list_models, f1_bf_cv.values(), alpha=0.5)
plt.grid(True)
plt.title('f1_bf_cv')
plt.savefig("05_hatzis_2011_bf_cv.png")

# %%
from sklearn.metrics import roc_auc_score, roc_curve


auc_lr = roc_auc_score(y_test_bf, lr.predict_proba(X_test)[:, 1])
fpr_lr, tpr_lr, thresholds_lr = roc_curve(y_test_bf, lr.predict_proba(X_test)[:, 1])

auc_knn = roc_auc_score(y_test_bf, knn.predict_proba(X_test)[:, 1])
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_test_bf, knn.predict_proba(X_test)[:, 1])

auc_rf = roc_auc_score(y_test_bf, rf.predict_proba(X_test)[:, 1])
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test_bf, rf.predict_proba(X_test)[:, 1])

auc_svc_lm = roc_auc_score(y_test_bf, svc_lm.predict_proba(X_test)[:, 1])
fpr_svc_lm, tpr_svc_lm, thresholds_lr = roc_curve(y_test_bf, svc_lm.predict_proba(X_test)[:, 1])

auc_dt = roc_auc_score(y_test_bf, dt.predict_proba(X_test)[:, 1])
fpr_dt, tpr_dt, thresholds_lr = roc_curve(y_test_bf, dt.predict_proba(X_test)[:, 1])

# %%
plt.figure(figsize=(12, 7))
plt.plot(fpr_lr, tpr_lr, label=f'AUC (Logistic Regression) = {auc_lr:.2f}')
plt.plot(fpr_dt, tpr_dt, label=f'AUC (Decision Tree) = {auc_dt:.2f}')
plt.plot(fpr_rf, tpr_rf, label=f'AUC (Random Forests) = {auc_rf:.2f}')
plt.plot(fpr_knn, tpr_knn, label=f'AUC (KNN) = {auc_knn:.2f}')
plt.plot(fpr_svc_lm, tpr_svc_lm, label=f'AUC (SVC_LM) = {auc_knn:.3f}')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Baseline')
plt.title('ROC Curve', size=20)
plt.xlabel('False Positive Rate', size=14)
plt.ylabel('True Positive Rate', size=14)
plt.grid(True)
plt.legend()
plt.savefig('roc_curve_bf')

# %% [markdown]
# #select svc_lm with best feature:
#
# mcc = 0.596
#
# f1 = 0.666
#
# auc = 0.758
#
#
# - svc_lm
# - minmax scaler
# - features selection
# - chi2
# - k = 4000
# - tts

# %%
os.listdir()
# Out:
# ['07_Magbanua MJ_2015_merge_resp_gene.csv',
#  '05_hatzis_2011_bf.png',
#  '07_Magbanua MJ_2015_gex_commun_c05.csv',
#  '05_hatzis_2011_rb_cv.png',
#  '05_hatzis_2011_TSS.png',
#  '05_hatzis_2011_bf_cv.png',
#  'TTS_RECIST_GEX_MLclassification.ipynb',
#  '05_hatzis_2011_merge_communc07_resp_gene.csv',
#  '03_Lisowska_2014_merg.csv',
#  '05_hatzis_2011_cv.png',
#  '04_iwamoto_2011_merge.csv',
#  '05_hatzis_2011_merge_communc07_resp_gene.ipynb',
#  '04_iwamoto_2011.ipynb',
#  '.ipynb_checkpoints',
#  '05_hatzis_2011_rb.png',
#  '.git',
#  'roc_curve_bf.png']

# %%
c7 = pd.read_csv('07_Magbanua MJ_2015_merge_resp_gene.csv')
c7.head()
# Out:
#      patient      response     NRIP1      APEH      MMP7      MBL2      LIPC  \
# 0  GSM808102  NonResponder  0.638788 -0.411659 -2.296739  0.599676 -0.252390
# 1  GSM808103  NonResponder  0.049577 -0.508247 -2.898622  0.225728  0.219263
# 2  GSM808104  NonResponder -0.372457  0.064547  0.723742  0.603895  0.215453
# 3  GSM808105  NonResponder  1.017304 -0.725764 -2.188842  0.057032 -0.024626
# 4  GSM808106  NonResponder  1.414880 -1.109260 -3.024599 -0.409354 -0.610967
#
#      HNRNPU    FERMT2    SCAF11  ...     GHITM      MUSK    DEPDC5      PRR7  \
# 0 -0.126299  0.257339 -0.108377  ...  0.876645 -0.176578 -0.277704 -0.341720
# 1 -0.939055  0.523286  0.253921  ...  0.201442  0.136619  0.130515 -0.334340
# 2 -0.540777  0.005355  0.341426  ...  0.575903  0.106606  0.523758 -0.506554
# 3  0.908507  0.494999  0.205639  ...  0.344062  0.165764  0.642756 -0.256828
# 4  0.260781  0.835511 -0.422035  ...  0.078259 -0.002483  0.595120  0.327405
#
# ...

# %%
c7 = c7.rename(columns={'patient':'Patient'}).set_index('Patient')

# %%
c7['response']=c7['response'].map({'NonResponder':0, 'Responder':1})

# %%
c7['response'].value_counts(normalize=True)
# Out:
# 0    0.746377
# 1    0.253623
# Name: response, dtype: float64

# %%
print(c5.shape)
print(c7.shape)
# Out:
# (306, 8994)
# (138, 8994)

# %%
pd.merge(c5.T.reset_index(),c7.T.reset_index(), on='index').shape
# Out:
# (8994, 445)

# %% [markdown]
# - check if they have the same name genes
#     - 445 = 138+306
#     - 8994 ==8994

# %%
c7.head()
# Out:
#            response     NRIP1      APEH      MMP7      MBL2      LIPC  \
# Patient
# GSM808102         0  0.638788 -0.411659 -2.296739  0.599676 -0.252390
# GSM808103         0  0.049577 -0.508247 -2.898622  0.225728  0.219263
# GSM808104         0 -0.372457  0.064547  0.723742  0.603895  0.215453
# GSM808105         0  1.017304 -0.725764 -2.188842  0.057032 -0.024626
# GSM808106         0  1.414880 -1.109260 -3.024599 -0.409354 -0.610967
#
#              HNRNPU    FERMT2    SCAF11      USP7  ...     GHITM      MUSK  \
# Patient                                            ...
# GSM808102 -0.126299  0.257339 -0.108377  0.583297  ...  0.876645 -0.176578
# GSM808103 -0.939055  0.523286  0.253921 -0.101986  ...  0.201442  0.136619
# GSM808104 -0.540777  0.005355  0.341426 -0.055783  ...  0.575903  0.106606
# GSM808105  0.908507  0.494999  0.205639  0.486430  ...  0.344062  0.165764
# GSM808106  0.260781  0.835511 -0.422035  0.223161  ...  0.078259 -0.002483
#
# ...

# %%
c7.isna().sum().sort_values(ascending=False).head()
# Out:
# KLK3      138
# MEP1A      61
# AQR        60
# RAB40A     56
# SNX13      56
# dtype: int64

# %%
c7.fillna(c7.mean(), axis=0, inplace=True) #replace nan by mean of the given column

# %%
c7['KLK3'].fillna(0, inplace=True) #i can't remove it

# %%
c7.isna().any(axis=0).unique() #no NAN now
# Out:
# array([False])

# %%
X_c7 = c7.drop('response', axis=1)
y_c7 = c7['response']

print(X_c7.shape,'\n',y_c7.shape)
# Out:
# (138, 8993)
#  (138,)

# %%
X_c7_sc = scaler.fit_transform(X_c7)

# %%
#get the index of best features with get_support function ==> boolean mask
best_f_c7 = kb.fit_transform(X_c7_sc,y_c7)
best_f_c7_name = np.array(pd.DataFrame(X_c7).columns)[kb.get_support()]
best_f_c7_name
# Out:
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/feature_selection/_univariate_selection.py:168: RuntimeWarning: divide by zero encountered in true_divide
#   chisq /= f_exp
# array(['NRIP1', 'APEH', 'MMP7', ..., 'SLC16A7', 'SPTBN5', 'MUSK'],
#       dtype=object)

# %%
#predict the seconde data c7
# make dictionnary
pred_c7_bf = {}
mcc_c7_bf = {}
f1_c7_bf = {}

#model in for loop 
for clf in models:
    np.average(cross_val_score(clf, best_f, y, cv=cv))
    pred_c7_bf[clf] = cross_val_predict(clf, best_f_c7, y_c7, cv=cv)
    mcc_c7_bf[clf] = matthews_corrcoef(y_c7, pred_c7_bf[clf])
    f1_c7_bf[clf] = f1_score(y_c7, pred_c7_bf[clf])
# Out:
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/ouahbi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.bar(list_models, mcc_c7_bf.values(), alpha=0.5, color='red')
plt.grid(True)
plt.title('mcc_bf_cv_predict_c7')
plt.subplot(122)
plt.bar(list_models, f1_c7_bf.values(), alpha=0.5)
plt.grid(True)
plt.title('f1_bf_cv_predict_c7')
plt.savefig("modelsFitOnC5_predict_c7.png")

# %%
lr.predict_proba(best_f_c7)[:, 1].shape
# Out:
# (138,)

# %%
y_c7.shape
# Out:
# (138,)

# %%
auc_lr_c7 = roc_auc_score(y_c7, lr.predict_proba(best_f_c7)[:, 1])
fpr_lr_c7, tpr_lr_c7, thresholds_lr_c7 = roc_curve(y_c7, lr.predict_proba(best_f_c7)[:, 1])

auc_knn_c7 = roc_auc_score(y_c7, knn.predict_proba(best_f_c7)[:, 1])
fpr_knn_c7, tpr_knn_c7, thresholds_knn_c7 = roc_curve(y_c7, knn.predict_proba(best_f_c7)[:, 1])

auc_rf_c7 = roc_auc_score(y_c7, rf.predict_proba(best_f_c7)[:, 1])
fpr_rf_c7, tpr_rf_c7, thresholds_rf_c7 = roc_curve(y_c7, rf.predict_proba(best_f_c7)[:, 1])

auc_svc_lm_c7 = roc_auc_score(y_c7, svc_lm.predict_proba(best_f_c7)[:, 1])
fpr_svc_lm_c7, tpr_svc_lm_c7, thresholds_lr_c7 = roc_curve(y_c7, svc_lm.predict_proba(best_f_c7)[:, 1])

auc_dt_c7 = roc_auc_score(y_c7, dt.predict_proba(best_f_c7)[:, 1])
fpr_dt_c7, tpr_dt_c7, thresholds_lr_c7 = roc_curve(y_c7, dt.predict_proba(best_f_c7)[:, 1])

# %%
plt.figure(figsize=(10, 7))
plt.plot(fpr_lr_c7, tpr_lr_c7, label=f'AUC (Logistic Regression) = {auc_lr_c7:.2f}')
plt.plot(fpr_dt_c7, tpr_dt_c7, label=f'AUC (Decision Tree) = {auc_dt_c7:.2f}')
plt.plot(fpr_rf_c7, tpr_rf_c7, label=f'AUC (Random Forests) = {auc_rf_c7:.2f}')
plt.plot(fpr_knn_c7, tpr_knn_c7, label=f'AUC (KNN) = {auc_knn_c7:.2f}')
plt.plot(fpr_svc_lm_c7, tpr_svc_lm_c7, label=f'AUC (SVC_LM) = {auc_knn_c7:.3f}')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Baseline')
plt.title('ROC Curve', size=20)
plt.xlabel('False Positive Rate', size=14)
plt.ylabel('True Positive Rate', size=14)
plt.grid(True)
plt.legend()
plt.savefig('roc_curve_c7_cv_bf')
