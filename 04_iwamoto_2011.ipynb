# %%
! ls
# Out:
# 04_iwamoto_2011_Analyse.ipynb	04_iwamoto_2011_clinical.csv  taka_2011.pdf
# 04_iwamoto_2011_Analyse.pdf	04_iwamoto_2011_gex.csv       Untitled.ipynb
# 04_iwamoto_2011_Analysis_files	04_iwamoto_2011_merge.xlsx
# 04_iwamoto_2011_Analysis.html	GSE22093.xlsx

# %%
import pandas as pd
df = pd.read_excel('GSE22093.xlsx', skiprows=80,engine='openpyxl', index_col=0)
df.head()
# Out:
#             GSM549230  GSM549231  GSM549232  GSM549233  GSM549234  GSM549235  \
# patient_ID
# 1007_s_at   11.656917  11.041608  12.569615  12.283743  11.954910  11.346717
# 1053_at      8.922276   7.645466   8.994505   8.073775   9.288642   8.488596
# 117_at       7.804426   8.405843   8.111465   8.268126   8.088217   7.879945
# 121_at      10.262535  10.574645  10.699021  10.718334  10.351885  10.397266
# 1255_g_at    6.568635   6.436035   6.463451   6.794077   6.356024   5.589475
#
#             GSM549236  GSM549237  GSM549238  GSM549239  ...  GSM750745  \
# patient_ID                                              ...
# 1007_s_at   10.708971  11.974445  11.987945  11.895960  ...  11.822675
# 1053_at      8.419631   8.548015   9.672984   7.479526  ...   8.727669
# 117_at       9.022433   7.913748   7.230985   8.278296  ...   7.841110
# 121_at      10.299554  10.663488  10.477249  10.153529  ...  10.124638
# 1255_g_at    7.300213   5.984576   6.681168   5.995690  ...   5.803980
#
# ...

# %%
df.shape
# Out:
# (22284, 103)

# %%
df = df.T

# %%
df.drop('!series_matrix_table_end', axis=1, inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.rename(columns={'index':'patient_ID'}, inplace=True)

# %%
df.head(2)
# Out:
# patient_ID patient_ID  1007_s_at   1053_at    117_at     121_at  1255_g_at  \
# 0           GSM549230  11.656917  8.922276  7.804426  10.262535   6.568635
# 1           GSM549231  11.041608  7.645466  8.405843  10.574645   6.436035
#
# patient_ID   1294_at   1316_at   1320_at  1405_i_at  ...  \
# 0           9.547638  7.792220  6.969494  10.506671  ...
# 1           9.926036  7.900622  5.775705  11.106255  ...
#
# patient_ID  AFFX-r2-Hs28SrRNA-5_at  AFFX-r2-Hs28SrRNA-M_at  \
# 0                         7.828237                9.697663
# 1                         6.032792                9.107146
#
# patient_ID  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  \
# 0                     15.663557             15.31085        4.182382
# 1                     15.558262             15.13942        4.874678
#
# patient_ID  AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  AFFX-TrpnX-5_at  \
# 0                 3.840668        5.555082         1.228357         3.174974
# ...

# %%
cd = pd.read_csv('04_iwamoto_2011_clinical.csv')
cd.shape
# Out:
# (103, 12)

# %%
cd.head(3)
# Out:
#   patient_ID     FNA biopsy RECIST tp53 status ER statut by geneExp  \
# 0  GSM549230  pre-treatment    pCR         MUT                ERneg
# 1  GSM549231  pre-treatment    pCR          WT                ERneg
# 2  GSM549232  pre-treatment    pCR         MUT                ERneg
#
#   ER statut by IHC   age  prechemo t      prechemo tumor size  prechemo n  \
# 0            ERneg  55.0         3.0  prechemo tumor size: NA         NaN
# 1            ERneg  52.0         3.0  prechemo tumor size: NA         NaN
# 2            ERpos  62.0         3.0  prechemo tumor size: NA         NaN
#
#    grade                                  NeoAdj_drug
# 0    3.0  5-Fluorouracil/Doxorubicin/Cyclophosphamide
# 1    3.0  6-Fluorouracil/Doxorubicin/Cyclophosphamide
# 2    3.0  7-Fluorouracil/Doxorubicin/Cyclophosphamide

# %%
merg = pd.merge(cd, df, on='patient_ID')

# %%
merg.shape
# Out:
# (103, 22295)

# %%
merg.to_csv('04_iwamoto_2011_merge.csv')
